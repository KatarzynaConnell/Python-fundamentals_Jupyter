# %%
import urllib.request

# %%
import io

# %%
import PIL.Image

# %%
URL = 'http://www.gmit.ie/sites/all/themes/gmitpublic/images/gmit_logo.png'

# %%
with urllib.request.urlopen(URL) as url:
    imagefile = io.BytesIO(url.read())
    image = PIL.Image.open(imagefile)
    imagebw = image.convert('L')

# %%
display(image, imagebw)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x95 at 0x2309E1B80F0>
# <PIL.Image.Image image mode=L size=300x95 at 0x230A004A828>

# %%
Many plotting packages exist, such as matplotlib:

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import matplotlib.pyplot as pl

# %%
x1 = np.linspace(0, 4 * np.pi, 1000)
y1 = np.sin(x1)
y2 = np.cos(x1)

x2 = np.linspace(0, 4 * np.pi, 9)
y3 = np.sin(x2)
y4 = np.cos(x2)

pl.plot(x1, y1)
pl.plot(x2, y3, 'r.')
pl.plot(x1, y2, 'g')
pl.plot(x2, y4, 'k.')

pl.show()

# %%
Python is an excellent choice for data analytics.

# %%
# %matplotlib inline
# Out:
#   File "<ipython-input-11-2940149d7ffc>", line 1
#     Python is an excellent choice for data analytics.
#                          ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
import matplotlib.pyplot as pl

# %%
pl.hist(np.random.normal(10, 2, 1000))
pl.show()
